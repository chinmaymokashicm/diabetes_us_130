# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned.csv")
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0      24437208          135        Caucasian  Female  [50-60)
# 1      29758806          378        Caucasian  Female  [50-60)
# 2     189899286          729        Caucasian  Female  [80-90)
# 3      64331490          774        Caucasian  Female  [80-90)
# 4      14824206          927  AfricanAmerican  Female  [30-40)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  2                         1                    1
# 1                  3                         1                    1
# 2                  1                         3                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital medical_specialty  ...  citoglipton  insulin  \
# 0                 8        Cardiology  ...           No   Steady
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
# Looping through X and Y variables
list_X = ["gender", "race", "age"]
list_Y = ["readmitted", "change", "insulin", "A1Cresult"]
for X in list_X:
    for Y in list_Y:
        # pd.crosstab(df[X], df[Y]).apply(lambda r: r/r.sum(), axis=1).plot(kind="barh")
        df_crosstab = pd.crosstab(df[X], df[Y], normalize="index", margins=False)
        # sns.heatmap(df_crosstab, cmap="rocket_r", annot=True, fmt="g")
        sns.heatmap(df_crosstab, cmap="rocket_r", annot=True, fmt=".2%")
        plt.show()

# %%
df_crosstab = pd.crosstab(df.A1Cresult, df.readmitted, margins=False)
sns.heatmap(df_crosstab, cmap="rocket_r", annot=True, fmt="g")
plt.show()
